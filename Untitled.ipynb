# %%
import pandas as pd

# %%
coffee_data = pd.read_csv("arabica_data_cleaned.csv")
coffee_data.head()

# %%
coffee_df = coffee_data[["Aroma","Flavor","Aftertaste","Acidity","Body","Balance","Uniformity","Clean.Cup","Sweetness","Cupper.Points", "Moisture","altitude_mean"]].copy()
coffee_df
# Out:
#       Aroma  Flavor  Aftertaste  Acidity  Body  Balance  Uniformity  \
# 0      8.67    8.83        8.67     8.75  8.50     8.42       10.00
# 1      8.75    8.67        8.50     8.58  8.42     8.42       10.00
# 2      8.42    8.50        8.42     8.42  8.33     8.42       10.00
# 3      8.17    8.58        8.42     8.42  8.50     8.25       10.00
# 4      8.25    8.50        8.25     8.50  8.42     8.33       10.00
# ...     ...     ...         ...      ...   ...      ...         ...
# 1305   7.00    6.33        6.17     6.50  6.67     6.17        8.00
# 1306   7.08    6.83        6.25     7.42  7.25     6.75       10.00
# 1307   6.75    6.58        6.42     6.67  7.08     6.67        9.33
# 1308   7.25    6.58        6.33     6.25  6.42     6.08        6.00
# 1309   7.50    6.67        6.67     7.67  7.33     6.67        8.00
#
#       Clean.Cup  Sweetness  Cupper.Points
# 0         10.00      10.00           8.75
# 1         10.00      10.00           8.58
# ...

# %%
coffee_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 10 columns):
# Aroma            1310 non-null float64
# Flavor           1310 non-null float64
# Aftertaste       1310 non-null float64
# Acidity          1310 non-null float64
# Body             1310 non-null float64
# Balance          1310 non-null float64
# Uniformity       1310 non-null float64
# Clean.Cup        1310 non-null float64
# Sweetness        1310 non-null float64
# Cupper.Points    1310 non-null float64
# dtypes: float64(10)
# memory usage: 102.5 KB
